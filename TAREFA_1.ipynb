# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoHSilva07/Paradigmas_Programacao/blob/main/TAREFA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aquisição de Dados - Texto foi inserido no disco local do Python**

# %%
texto = []

f = open('/Tarefa 1 - Resumo La Casa de Papel.txt','r')    # para arquivos locais
for line in f:
  texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "
    texto[i] = texto[i].replace('/','\n')

# %% [markdown]
# **Construção do Dicionário - Utilizada mesma estrutura apresentada**

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'a': 54, 'série': 2, 'começa': 2, 'com': 25, 'formação': 1, 'do': 41, 'grupo': 14, 'de': 48, 'assaltantes': 5, 'sequestradores': 4, 'que': 56, 'vão': 2, 'colocar': 1, 'em': 25, 'prática': 1, 'o': 79, 'plano': 12, 'assalto': 5, 'oito': 2, 'pessoas': 3, 'diferentes': 2, 'especialidades': 1, 'são': 5, 'escolhidas': 1, 'para': 33, 'este': 1, 'seleto': 1, 'criminosos': 1, 'e': 76, 'cada': 3, 'um': 26, 'é': 32, 'chamado': 1, 'pelo': 8, 'nome': 3, 'uma': 23, 'cidade': 1, 'mundo:': 1, 'tóquio': 13, 'berlim': 8, 'denver': 11, 'moscou': 6, 'oslo': 2, 'helsinque': 3, 'nairobi': 5, 'rio': 13, 'mente': 1, 'por': 19, 'trás': 2, 'professor': 22, 'homem': 1, 'calculista': 1, 'envergonhado': 1, 'reúne': 1, 'seus': 2, 'soldados': 1, 'cinco': 1, 'meses': 1, 'casa': 13, 'na': 13, 'zona': 1, 'rural': 2, 'toledo': 2, 'lá': 3, 'como': 7, 'ele': 11, 'repassa': 1, 'os': 23, 'detalhes': 1, 'todas': 1, 'as': 7, 'variáveis': 1, 'dos': 9, 'acontecimentos': 1, 'só': 4, 'mais': 1, 'tenha': 1, 'pensado': 1, 'tudo': 5, 'alguma': 1, 'coisa': 1, 'sempre': 1, 'acaba': 4, 'dando': 1, 'escapadinha': 1, 'vai': 5, 'vendo': 1, 'acontece': 2, 'logo': 2, 'no': 8, 'primeiro': 1, 'episódio': 1, 'macacões': 1, 'vermelhos': 1, 'máscaras': 2, 'caricatas': 1, 'salvador': 1, 'dalí': 2, 'invade': 1, 'da': 25, 'moeda': 9, 'faz': 8, '67': 1, 'reféns': 10, 'entre': 5, 'funcionários': 1, 'adolescentes': 1, 'excursão': 1, 'três': 3, 'se': 17, 'destacam:': 1, 'alison': 2, 'parker': 2, 'filha': 1, 'embaixador': 1, 'reino': 1, 'unido;': 1, 'arturo': 11, 'román': 1, 'diretor': 2, 'moeda;': 1, 'mônica': 2, 'gaztambide': 1, 'secretária': 1, 'amante': 1, 'descobrir': 1, 'está': 7, 'grávida': 1, 'dele': 4, 'lado': 4, 'fora': 4, 'dentro': 9, 'coisas': 1, 'começam': 2, 'ficar': 1, 'complicadas': 1, 'surgem': 1, 'até': 5, 'envolvimentos': 1, 'amorosos': 1, 'não': 4, 'deveriam': 1, 'existir': 1, 'aliás': 1, 'relações': 1, 'amorosas': 1, 'personagens': 1, 'maiores': 2, 'pontos': 1, 'fracos:': 1, 'apaixonado': 3, 'apaixona': 1, 'ela': 18, 'apaixonam': 1, 'desde': 1, 'começo': 1, 'mas': 20, 'também': 3, 'chama': 1, 'atenção': 2, 'ariadna': 1, 'relação': 1, 'bem': 3, 'abusiva': 1, 'ainda': 3, 'tem': 3, 'junto': 2, 'raquel': 10, 'parte': 1, 'coração': 1, 'pobre': 1, 'policial': 5, 'angel': 5, 'brutamontes': 1, 'sente': 1, 'algo': 1, 'desses': 1, 'salvam': 1, '-': 4, 'filho': 2, 'forte': 1, 'amizade': 1, 'já': 4, 'tinha': 1, 'demonstrado': 1, 'certo': 2, 'interesse': 1, 'passa': 2, 'mal': 1, 'ao': 4, 'pensar': 1, 'pode': 1, 'ter': 1, 'matado': 1, 'monica': 4, 'leva': 2, 'pai': 1, 'outros': 2, 'respirar': 1, 'pouco': 1, 'topo': 1, 'banco': 8, 'descobre': 2, 'foi': 3, '“morta”': 1, 'surta': 1, 'estão': 5, 'todos': 8, 'vestidos': 2, 'vermelho': 2, 'mascarados': 1, 'desconfia': 1, 'dá': 4, 'luz': 1, 'verde': 1, 'atiradores': 1, 'elite': 1, 'ferido': 1, 'médicos': 1, 'autorizado': 1, 'entrar': 3, 'infiltrado': 1, 'grampeado': 1, 'ouve': 1, 'planos': 1, 'antecede': 1, 'ações': 1, 'polícia': 12, 'afastado': 1, 'suspeita': 1, 'ser': 2, 'informante': 1, 'volta': 3, 'desconfiada': 1, 'suspeitas': 1, 'porém': 1, 'dão': 1, 'nada': 1, 'dois': 4, 'dormem': 1, 'juntos': 1, 'enquanto': 3, 'isso': 6, 'arma': 5, 'fuga': 1, 'funciona': 1, 'resulta': 1, 'invasão': 2, 'local': 1, 'consegue': 4, 'fazê-los': 1, 'recuar': 3, 'atirando': 1, 'metralhadora': 1, 'agora': 4, 'sem': 4, '16': 1, 'saber': 1, 'fazer': 2, 'contato': 4, 'vota': 1, 'esperar': 1, 'ou': 1, 'executar': 2, '“plano': 1, 'chernobyl”': 1, 'furioso': 2, 'atitudes': 1, 'coloca': 2, 'lugar': 2, 'primeira': 1, 'presa': 2, 'preso': 1, 'agressão': 2, 'autoridade': 1, 'livre': 1, 'processo': 1, 'entanto': 2, 'revoltada': 1, 'revela': 1, 'verdadeiro': 1, 'professor:': 1, 'sergio': 1, 'marquina': 1, 'indignado': 1, 'fez': 1, 'conta': 1, 'bandidos:': 1, 'fugir': 1, 'buraco': 1, 'diferente': 3, 'eles': 4, 'cavando': 1, 'fica': 5, 'prestes': 1, 'quando': 2, 'finalmente': 1, 'telefone': 2, 'toca': 1, 'atende': 2, 'pancada': 1, 'cabeça': 3, 'assume': 1, 'controle': 1, 'b ...

# %% [markdown]
# **Exibição dos Resultados - Plotando o gráfico em barras de linhas**

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências

plt.figure(figsize=(18,20))
mpl.style.use(['seaborn'])
x=df.word
y=df['count']
sns.barplot(y,x)
plt.xticks(rotation=90) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
