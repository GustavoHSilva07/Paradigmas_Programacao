# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoHSilva07/Paradigmas_Programacao/blob/main/TAREFA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. PDF de Print do notebook
#
# **Aquisição de Dados - Texto foi inserido no disco local do Python**

# %%
texto = []

f = open('/Tarefa 1 - Resumo La Casa de Papel.txt','r')    # para arquivos locais
for line in f:
  texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "
    texto[i] = texto[i].replace('/','\n')

# %% [markdown]
# **Construção do Dicionário - Utilizada mesma estrutura apresentada**

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'a': 54, 'série': 2, 'começa': 2, 'com': 25, 'formação': 1, 'do': 41, 'grupo': 14, 'de': 48, 'assaltantes': 5, 'sequestradores': 4, 'que': 56, 'vão': 2, 'colocar': 1, 'em': 25, 'prática': 1, 'o': 79, 'plano': 12, 'assalto': 5, 'oito': 2, 'pessoas': 3, 'diferentes': 2, 'especialidades': 1, 'são': 5, 'escolhidas': 1, 'para': 33, 'este': 1, 'seleto': 1, 'criminosos': 1, 'e': 76, 'cada': 3, 'um': 26, 'é': 32, 'chamado': 1, 'pelo': 8, 'nome': 3, 'uma': 23, 'cidade': 1, 'mundo:': 1, 'tóquio': 13, 'berlim': 8, 'denver': 11, 'moscou': 6, 'oslo': 2, 'helsinque': 3, 'nairobi': 5, 'rio': 13, 'mente': 1, 'por': 19, 'trás': 2, 'professor': 22, 'homem': 1, 'calculista': 1, 'envergonhado': 1, 'reúne': 1, 'seus': 2, 'soldados': 1, 'cinco': 1, 'meses': 1, 'casa': 13, 'na': 13, 'zona': 1, 'rural': 2, 'toledo': 2, 'lá': 3, 'como': 7, 'ele': 11, 'repassa': 1, 'os': 23, 'detalhes': 1, 'todas': 1, 'as': 7, 'variáveis': 1, 'dos': 9, 'acontecimentos': 1, 'só': 4, 'mais': 1, 'tenha': 1, 'pensado': 1, 'tudo'
# ...

# %% [markdown]
# **Exibição dos Resultados - Plotando o gráfico em barras de linhas**

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências

plt.figure(figsize=(18,14))
mpl.style.use(['seaborn'])
x=df.word
y=df['count']
sns.barplot(y,x)
plt.xticks(rotation=90) 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 2. Compartilhe o endereço do seu notebook Python (Google Drive ou GitHub) 100% executável para abertura no Google Colab.
#
# https://github.com/GustavoHSilva07/Paradigmas_Programacao

# %% [markdown]
# # 3. Não deixe de incluir o seu texto uma introdução justificando o texto escolhido e ao final suas conclusões.
#
# **Introdução**
#
# Para a realização da atividade selecionei um texto do resumo de La Casa de Papel que é a série mais assistida da Netflix no mundo. Através de algoritmos com a mesma ideia das buscas realizadas pelo cliente em seu perfil e correlacionando com as sinopses dos últimos produtos consumidos na plataforma de streams acredito ser possível traçar o perfil e fazer novas sugestões para prender o cliente. A ideia por trás da escolha do texto foi implementar o algoritmo em algo real e do dia a dia.
#
# **Conclusão**
#
# A tarefa permitiu empregar vários conceitos da aula como manipulação de dicionários e estruturas de looping e alguns mais que necessitou de pesquisa forçando o desenvolvimento no assunto. Considero importante corelacionar as atividades e aprendizados com tarefas do mundo real o que perfeitamente se encaixa aqui uma vez que esses algoritmos de busca de palavras são amplamente utilizados no nosso dia a dia em plataformas como a Netfix que constroi o perfil dos usuários para mandar indicações e prender o público ou mesmo em coisas simples como pesquisas rescentes e complementos de texto pela quantidade de vezes que já utilizou certa palavra.
# Outro ponto interessante foi a implementação de uma biblioteca que permite plotar gráficos de maneira bem simples.
